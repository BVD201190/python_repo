# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')

# %%
df
# Out:
#                                             Indicator PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# ...                                               ...            ...   ...
# 4651  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4652  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4653  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4654  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4655  Healthy life expectancy (HALE) at birth (years)      Published  2012
#
#                  WHO region World Bank income group               Country  \
# 0                    Europe             High-income               Andorra
# 1                    Europe             High-income               Andorra
# 2                    Europe             High-income               Andorra
# 3                    Europe             High-income               Andorra
# 4     Eastern Mediterranean             High-income  United Arab Emirates
# ...                     ...                     ...                   ...
# 4651        Western Pacific     Lower-middle-income                 Samoa
# 4652  Eastern Mediterranean              Low-income                 Yemen
# 4653                 Africa     Upper-middle-income          South Africa
# 4654                 Africa              Low-income                Zambia
# 4655                 Africa              Low-income              Zimbabwe
#
#              Sex  Display Value  Numeric  Low  High  Comments
# 0     Both sexes             77     77.0  NaN   NaN       NaN
# 1     Both sexes             80     80.0  NaN   NaN       NaN
# 2         Female             28     28.0  NaN   NaN       NaN
# 3     Both sexes             23     23.0  NaN   NaN       NaN
# 4         Female             78     78.0  NaN   NaN       NaN
# ...          ...            ...      ...  ...   ...       ...
# 4651      Female             66     66.0  NaN   NaN       NaN
# 4652  Both sexes             54     54.0  NaN   NaN       NaN
# 4653        Male             49     49.0  NaN   NaN       NaN
# 4654  Both sexes             36     36.0  NaN   NaN       NaN
# 4655      Female             51     51.0  NaN   NaN       NaN
#
# [4656 rows x 12 columns]

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')

# %%
df1
# Out:
#                   STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  \
# 0       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999
# 1       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999
# 2       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999
# 3       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999
# 4       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999
# ...                   ...                  ...       ...   ...   ...   ...
# 117203  GHCND:GMM00010385        SCHONEFELD GM  19921227     0 -9999 -9999
# 117204  GHCND:GMM00010385        SCHONEFELD GM  19921228     0 -9999 -9999
# 117205  GHCND:GMM00010385        SCHONEFELD GM  19921229     0 -9999 -9999
# 117206  GHCND:GMM00010385        SCHONEFELD GM  19921230     0 -9999 -9999
# 117207  GHCND:GMM00010385        SCHONEFELD GM  19921231     3 -9999 -9999
#
#         TMAX  TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  \
# 0      -9999   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1         50    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2         28    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3         39    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4          0   -22 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# ...      ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...   ...
# 117203    10   -95 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 117204   -16 -9999 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 117205 -9999 -9999 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 117206 -9999   -37 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 117207    -7 -9999 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#         WT08  WT18  WT03
# 0      -9999 -9999 -9999
# 1      -9999 -9999 -9999
# 2      -9999 -9999 -9999
# 3      -9999 -9999 -9999
# 4      -9999 -9999 -9999
# ...      ...   ...   ...
# 117203 -9999 -9999 -9999
# 117204 -9999 -9999 -9999
# 117205 -9999 -9999 -9999
# 117206 -9999 -9999 -9999
# 117207 -9999 -9999 -9999
#
# [117208 rows x 21 columns]

# %%
#1. Get the Metadata from the above files.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Indicator                4656 non-null   object
#  1   PUBLISH STATES           4656 non-null   object
#  2   Year                     4656 non-null   int64
#  3   WHO region               4656 non-null   object
#  4   World Bank income group  4656 non-null   object
#  5   Country                  4656 non-null   object
#  6   Sex                      4656 non-null   object
#  7   Display Value            4656 non-null   int64
#  8   Numeric                  4656 non-null   float64
#  9   Low                      0 non-null      float64
#  10  High                     0 non-null      float64
#  11  Comments                 0 non-null      float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   STATION       117208 non-null  object
#  1   STATION_NAME  117208 non-null  object
#  2   DATE          117208 non-null  int64
#  3   PRCP          117208 non-null  int64
#  4   SNWD          117208 non-null  int64
#  5   SNOW          117208 non-null  int64
#  6   TMAX          117208 non-null  int64
#  7   TMIN          117208 non-null  int64
#  8   WDFG          117208 non-null  int64
#  9   PGTM          117208 non-null  int64
#  10  WSFG          117208 non-null  int64
#  11  WT09          117208 non-null  int64
#  12  WT07          117208 non-null  int64
#  13  WT01          117208 non-null  int64
#  14  WT06          117208 non-null  int64
#  15  WT05          117208 non-null  int64
#  16  WT04          117208 non-null  int64
#  17  WT16          117208 non-null  int64
#  18  WT08          117208 non-null  int64
#  19  WT18          117208 non-null  int64
#  20  WT03          117208 non-null  int64
# dtypes: int64(19), object(2)
# memory usage: 18.8+ MB

# %%
#2. Get the row names from the above files.
#np.arange()
np.arange(len(df) , dtype= 'int64')
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
np.arange(len(df1), dtype = 'int64')
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %%
#3. Change the column name from any of the above file.
df.rename(columns = {'Indicator':'Indicator_id'}).head(2)
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
#4. Change the column name from any of the above file and store the changes made permanently.

df.rename(columns = {'Indicator':'Indicator_id'}, inplace = True)
df.head(2)
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
#5 Change the names of multiple columns.
df.rename(columns = {'Indicator':'Indicator_id','PUBLISH STATES':'Publication Status','WHO region':'WHO Region'}).head(2)
# Out:
#                        Indicator_id Publication Status  Year WHO Region  \
# 0  Life expectancy at birth (years)          Published  1990     Europe
# 1  Life expectancy at birth (years)          Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
#6 Arrange values of a particular column in ascending order.
df.sort_values('Year',ascending = True).head(10)
# Out:
#                            Indicator_id PUBLISH STATES  Year       WHO region  \
# 0      Life expectancy at birth (years)      Published  1990           Europe
# 1270   Life expectancy at birth (years)      Published  1990           Europe
# 3193   Life expectancy at birth (years)      Published  1990           Europe
# 3194   Life expectancy at birth (years)      Published  1990           Europe
# 3197  Life expectancy at age 60 (years)      Published  1990           Europe
# 1264   Life expectancy at birth (years)      Published  1990           Europe
# 3199  Life expectancy at age 60 (years)      Published  1990           Europe
# 1262  Life expectancy at age 60 (years)      Published  1990  Western Pacific
# 1259   Life expectancy at birth (years)      Published  1990  Western Pacific
# 3203  Life expectancy at age 60 (years)      Published  1990  South-East Asia
#
#      World Bank income group              Country         Sex  Display Value  \
# 0                High-income              Andorra  Both sexes             77
# 1270             High-income              Germany        Male             72
# 3193     Lower-middle-income  Republic of Moldova        Male             65
# 3194     Lower-middle-income  Republic of Moldova  Both sexes             68
# 3197     Lower-middle-income  Republic of Moldova        Male             15
# 1264             High-income               Cyprus  Both sexes             76
# 3199     Lower-middle-income  Republic of Moldova  Both sexes             17
# 1262             High-income         Cook Islands        Male             17
# 1259             High-income         Cook Islands        Male             67
# 3203     Lower-middle-income             Maldives      Female             12
#
#       Numeric  Low  High  Comments
# 0        77.0  NaN   NaN       NaN
# 1270     72.0  NaN   NaN       NaN
# 3193     65.0  NaN   NaN       NaN
# 3194     68.0  NaN   NaN       NaN
# 3197     15.0  NaN   NaN       NaN
# 1264     76.0  NaN   NaN       NaN
# 3199     17.0  NaN   NaN       NaN
# 1262     17.0  NaN   NaN       NaN
# 1259     67.0  NaN   NaN       NaN
# 3203     12.0  NaN   NaN       NaN

# %%
#7. Arrange multiple column values in ascending order.
df[['Indicator_id','Country','Year','WHO region','PUBLISH STATES']].sort_values(by = ['Indicator_id','Country','Year','WHO region','PUBLISH STATES'],ascending = True,ignore_index = True).head(10)
# Out:
#                                       Indicator_id      Country  Year  \
# 0  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2000
# 1  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2000
# 2  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2000
# 3  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2012
# 4  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2012
# 5  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2012
# 6  Healthy life expectancy (HALE) at birth (years)      Albania  2000
# 7  Healthy life expectancy (HALE) at birth (years)      Albania  2000
# 8  Healthy life expectancy (HALE) at birth (years)      Albania  2000
# 9  Healthy life expectancy (HALE) at birth (years)      Albania  2012
#
#               WHO region PUBLISH STATES
# 0  Eastern Mediterranean      Published
# 1  Eastern Mediterranean      Published
# 2  Eastern Mediterranean      Published
# 3  Eastern Mediterranean      Published
# 4  Eastern Mediterranean      Published
# 5  Eastern Mediterranean      Published
# 6                 Europe      Published
# 7                 Europe      Published
# 8                 Europe      Published
# 9                 Europe      Published

# %%
#8. Make country as the first column of the dataframe.

df[['Country','Indicator_id','PUBLISH STATES','Year','WHO region','World Bank income group','Sex','Display Value','Numeric','Low','High','Comments']].head(2)
# Out:
#    Country                      Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Andorra  Life expectancy at birth (years)      Published  1990     Europe
# 1  Andorra  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group         Sex  Display Value  Numeric  Low  High  \
# 0             High-income  Both sexes             77     77.0  NaN   NaN
# 1             High-income  Both sexes             80     80.0  NaN   NaN
#
#    Comments
# 0       NaN
# 1       NaN

# %%
#9. Get the column array using a variable

np.array(df[['WHO region']], dtype = 'object')
# Out:
# array([['Europe'],
#        ['Europe'],
#        ['Europe'],
#        ...,
#        ['Africa'],
#        ['Africa'],
#        ['Africa']], dtype=object)

# %%
#10 Get the subset rows 11, 24, 37

df.loc[[11,24,37]]
# Out:
#                          Indicator_id PUBLISH STATES  Year       WHO region  \
# 11   Life expectancy at birth (years)      Published  2012           Europe
# 24  Life expectancy at age 60 (years)      Published  2012  Western Pacific
# 37  Life expectancy at age 60 (years)      Published  2012           Europe
#
#    World Bank income group            Country     Sex  Display Value  Numeric  \
# 11             High-income            Austria  Female             83     83.0
# 24             High-income  Brunei Darussalam  Female             21     21.0
# 37             High-income             Cyprus  Female             26     26.0
#
#     Low  High  Comments
# 11  NaN   NaN       NaN
# 24  NaN   NaN       NaN
# 37  NaN   NaN       NaN

# %%
#11. Get the subset rows excluding 5, 12, 23, and 56

df.drop(index=[5,12,23,56],axis=0).head(7)
# Out:
#                         Indicator_id PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
# 6  Life expectancy at age 60 (years)      Published  1990
# 7  Life expectancy at age 60 (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
# 6               Americas             High-income   Antigua and Barbuda
# 7               Americas             High-income   Antigua and Barbuda
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# 2      Female             28     28.0  NaN   NaN       NaN
# 3  Both sexes             23     23.0  NaN   NaN       NaN
# 4      Female             78     78.0  NaN   NaN       NaN
# 6        Male             17     17.0  NaN   NaN       NaN
# 7  Both sexes             22     22.0  NaN   NaN       NaN

# %%
#12  Join users to transactions, keeping all rows from transactions and only matching rows from users (left join)

users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
products = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
transactions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
transactions.join(users.set_index('UserID'), on = 'UserID', how = 'left')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# 4    male  2010-08-01  2010-08-08
# 5    male  2010-08-01  2010-08-08
# 6  female  2012-10-23  2016-06-07
# 7     NaN         NaN         NaN
# 8     NaN         NaN         NaN
# 9  female  2012-10-23  2016-06-07

# %%
#13. Which transactions have a UserID not in users?

result = transactions.merge(users, on = 'UserID',how = 'left')
result = result[pd.isnull(result['User'])]
result.dropna(axis=1,how='all')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %%
transactions.merge(users, on = 'UserID',how = 'left')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# 4    male  2010-08-01  2010-08-08
# 5    male  2010-08-01  2010-08-08
# 6  female  2012-10-23  2016-06-07
# 7     NaN         NaN         NaN
# 8     NaN         NaN         NaN
# 9  female  2012-10-23  2016-06-07

# %%
#14. Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join)

transactions.join(users.set_index('UserID'), on = 'UserID',how = 'inner')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 6              7      2013-12-30     3.0          4         1  Caroline
# 9             10      2016-05-08     3.0          4         4  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 6  female  2012-10-23  2016-06-07
# 9  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# 4    male  2010-08-01  2010-08-08
# 5    male  2010-08-01  2010-08-08

# %%
#15. Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)

transactions.merge(users, how = 'outer', left_on = 'UserID', right_on = 'UserID')
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
#     Gender  Registered   Cancelled
# 0      NaN         NaN         NaN
# 1      NaN         NaN         NaN
# 2   female  2012-10-23  2016-06-07
# 3   female  2012-10-23  2016-06-07
# 4   female  2012-10-23  2016-06-07
# 5   female  2012-10-23  2016-06-07
# 6     male  2012-12-21         NaN
# 7     male  2010-08-01  2010-08-08
# 8     male  2010-08-01  2010-08-08
# 9      NaN         NaN         NaN
# 10  female  2013-07-17         NaN
# 11    male  2010-11-25         NaN

# %%
#16. Determine which sessions occurred on the same day each user registered
users.merge(sessions, how = 'inner', left_on = ['UserID','Registered'], right_on = ['UserID','SessionDate'])
# Out:
#    UserID     User  Gender  Registered   Cancelled  SessionID SessionDate
# 0       2    Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 1       4  Brielle  female  2013-07-17         NaN          9  2013-07-17

# %%
#17. Build a dataset with every possible (UserID, ProductID) pair (cross join)

# %%
users['key'] = 1
products['key'] = 1

products.head()
crossjoin = pd.merge(users,products, on = 'key')
crossjoin[['UserID','ProductID']]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %%
#18. Determine how much quantity of each product was purchased by each user

a = crossjoin.merge(transactions, how = 'left',left_on = ['UserID','ProductID'], right_on = ['UserID','ProductID'])
purchase = a.groupby(['UserID','ProductID'])['Quantity'].sum().reset_index()
purchase
# Out:
#     UserID  ProductID  Quantity
# 0        1          1       0.0
# 1        1          2       3.0
# 2        1          3       0.0
# 3        1          4       0.0
# 4        1          5       0.0
# 5        2          1       0.0
# 6        2          2       0.0
# 7        2          3       0.0
# 8        2          4       1.0
# 9        2          5       6.0
# 10       3          1       0.0
# 11       3          2       0.0
# 12       3          3       1.0
# 13       3          4       6.0
# 14       3          5       0.0
# 15       4          1       0.0
# 16       4          2       0.0
# 17       4          3       0.0
# 18       4          4       0.0
# 19       4          5       0.0
# 20       5          1       0.0
# 21       5          2       0.0
# 22       5          3       0.0
# 23       5          4       0.0
# 24       5          5       0.0

# %%
#19. For each user, get each possible pair of pair transactions (TransactionID1, TransacationID2)

# %%
transactions.merge(transactions, on = 'UserID',how = 'inner')
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# 12                7        2013-12-30     3.0            4           1
# 13                7        2013-12-30     3.0            4           1
# 14                7        2013-12-30     3.0            4           1
# 15                7        2013-12-30     3.0            4           1
# 16               10        2016-05-08     3.0            4           4
# 17               10        2016-05-08     3.0            4           4
# 18               10        2016-05-08     3.0            4           4
# 19               10        2016-05-08     3.0            4           4
# 20                4        2012-08-26     1.0            2           3
# 21                5        2013-06-06     2.0            4           1
# 22                5        2013-06-06     2.0            4           1
# 23                6        2013-12-23     2.0            5           6
# 24                6        2013-12-23     2.0            5           6
# 25                8        2014-04-24     NaN            2           3
#
#     TransactionID_y TransactionDate_y  ProductID_y  Quantity_y
# 0                 1        2010-08-21            2           1
# 1                 9        2015-04-24            4           3
# 2                 1        2010-08-21            2           1
# 3                 9        2015-04-24            4           3
# 4                 2        2011-05-26            4           1
# 5                 3        2011-06-16            3           1
# 6                 7        2013-12-30            4           1
# 7                10        2016-05-08            4           4
# 8                 2        2011-05-26            4           1
# 9                 3        2011-06-16            3           1
# 10                7        2013-12-30            4           1
# 11               10        2016-05-08            4           4
# 12                2        2011-05-26            4           1
# 13                3        2011-06-16            3           1
# 14                7        2013-12-30            4           1
# 15               10        2016-05-08            4           4
# 16                2        2011-05-26            4           1
# 17                3        2011-06-16            3           1
# 18                7        2013-12-30            4           1
# 19               10        2016-05-08            4           4
# 20                4        2012-08-26            2           3
# 21                5        2013-06-06            4           1
# 22                6        2013-12-23            5           6
# 23                5        2013-06-06            4           1
# 24                6        2013-12-23            5           6
# 25                8        2014-04-24            2           3

# %%
#20. Join each user to his/her first occuring transaction in the transactions table

users.merge(transactions.drop_duplicates('UserID'), on = 'UserID',how = 'left')
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2       3  Caroline  female  2012-10-23  2016-06-07            2.0
# 3       4   Brielle  female  2013-07-17         NaN            NaN
# 4       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaN        NaN       NaN
# 4             NaN        NaN       NaN

# %%
#21 Test to see if we can drop columns

# %%
data = users.merge(transactions.drop_duplicates('UserID'), on = 'UserID',how = 'left')
my_columns = list(data.columns)

# %%
my_columns
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
list(data.dropna(thresh=int(data.shape[0] * .9), axis=1).columns) #set threshold to drop NAs
# Out:
# ['UserID', 'User', 'Gender', 'Registered']

# %%
missing_info = list(data.columns[data.isnull().any()])

# %%
missing_info
# Out:
# ['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']

# %%
for col in missing_info:
    num_missing = data[data[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col, num_missing))
# Out:
# number missing for column Cancelled: 3
# number missing for column TransactionID: 2
# number missing for column TransactionDate: 2
# number missing for column ProductID: 2
# number missing for column Quantity: 2

# %%
for col in missing_info:
    percent_missing = data[data[col].isnull() == True].shape[0] / data.shape[0]
    print('percent missing for column {}: {}'.format(col, percent_missing))
# Out:
# percent missing for column Cancelled: 0.6
# percent missing for column TransactionID: 0.4
# percent missing for column TransactionDate: 0.4
# percent missing for column ProductID: 0.4
# percent missing for column Quantity: 0.4
